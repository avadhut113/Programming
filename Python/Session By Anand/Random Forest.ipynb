# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Reading the csv file and putting it into 'df' object.
df = pd.read_csv('Credit_Card_Details.csv')
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  defaulted
# 0         0         0         0          1
# 1      1000         0      2000          1
# 2      1000      1000      5000          0
# 3      1100      1069      1000          0
# 4      9000       689       679          0
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6     defaulted
# count   30000.000000  30000.000000
# mean     5215.502567      0.221200
# std     17777.465775      0.415062
# min         0.000000      0.000000
# 25%       117.750000      0.000000
# 50%      1500.000000      0.000000
# 75%      4000.000000      0.000000
# max    528666.000000      1.000000
#
# [8 rows x 25 columns]

# %%
# Let's understand the type of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   SEX        30000 non-null  int64
#  3   EDUCATION  30000 non-null  int64
#  4   MARRIAGE   30000 non-null  int64
#  5   AGE        30000 non-null  int64
#  6   PAY_0      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  int64
#  13  BILL_AMT2  30000 non-null  int64
#  14  BILL_AMT3  30000 non-null  int64
#  15  BILL_AMT4  30000 non-null  int64
#  16  BILL_AMT5  30000 non-null  int64
#  17  BILL_AMT6  30000 non-null  int64
#  18  PAY_AMT1   30000 non-null  int64
#  19  PAY_AMT2   30000 non-null  int64
#  20  PAY_AMT3   30000 non-null  int64
#  21  PAY_AMT4   30000 non-null  int64
#  22  PAY_AMT5   30000 non-null  int64
#  23  PAY_AMT6   30000 non-null  int64
#  24  defaulted  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('defaulted',axis=1)

y = df['defaulted']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.70, random_state=100)

# %%
# Importing random forest classifier from sklearn library
from sklearn.ensemble import RandomForestClassifier

mod_rfc = RandomForestClassifier()

# %%
mod_rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# Making predictions
predictions = mod_rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      6927
#            1       0.68      0.38      0.49      2073
#
#     accuracy                           0.82      9000
#    macro avg       0.76      0.66      0.69      9000
# weighted avg       0.80      0.82      0.80      9000

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[6553  374]
#  [1278  795]]

# %%
print(accuracy_score(y_test,predictions))
# Out:
# 0.8164444444444444

# %% [markdown]
# ### Tuning max_features

# %%
# GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'max_features': [4, 8, 14, 20, 24]}

rf = RandomForestClassifier(max_depth=4)


rf = GridSearchCV(rf, parameters, 
                    cv=n_folds, 
                   scoring="accuracy",return_train_score=True)
rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(max_depth=4),
#              param_grid={'max_features': [4, 8, 14, 20, 24]},
#              return_train_score=True, scoring='accuracy')

# %%
# scores of GridSearch CV
scores = rf.cv_results_
pd.DataFrame(scores).head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.011948      0.037524         0.029333        0.005238
# 1       2.072987      0.096372         0.032951        0.003944
# 2       3.523430      0.154333         0.030712        0.001255
# 3       4.881075      0.296786         0.031201        0.009592
# 4       5.816861      0.193551         0.034129        0.005181
#
#   param_max_features                params  split0_test_score  \
# 0                  4   {'max_features': 4}           0.815000
# 1                  8   {'max_features': 8}           0.822857
# 2                 14  {'max_features': 14}           0.822143
# 3                 20  {'max_features': 20}           0.821905
# 4                 24  {'max_features': 24}           0.822619
#
#    split1_test_score  split2_test_score  split3_test_score  ...  \
# 0           0.810952           0.814286           0.808095  ...
# 1           0.819762           0.829524           0.821667  ...
# 2           0.819048           0.827619           0.820952  ...
# 3           0.818095           0.827143           0.819524  ...
# 4           0.819524           0.826667           0.821429  ...
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.812333        0.002522                5            0.814345
# 1         0.822762        0.003565                1            0.824643
# 2         0.821762        0.003157                3            0.824702
# 3         0.821429        0.003115                4            0.824762
# 4         0.821952        0.002636                2            0.824643
#
#    split1_train_score  split2_train_score  split3_train_score  \
# 0            0.815060            0.813393            0.814464
# 1            0.825833            0.823512            0.825238
# 2            0.825774            0.823333            0.825417
# 3            0.825774            0.824286            0.825238
# 4            0.826905            0.823810            0.826369
#
#    split4_train_score  mean_train_score  std_train_score
# 0            0.814107          0.814274         0.000541
# 1            0.824524          0.824750         0.000776
# 2            0.825655          0.824976         0.000902
# 3            0.824583          0.824929         0.000524
# 4            0.825952          0.825536         0.001142
#
# [5 rows x 21 columns]

# %%
# plotting accuracies with max_features
plt.figure()
plt.plot(scores["param_max_features"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_max_features"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("max_features")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ### Tuning min_samples_leaf

# %%
# GridSearchCV to find optimal min_samples_leaf
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'min_samples_leaf': range(100, 400, 50)}

# instantiate the model
rf = RandomForestClassifier()


# fit tree on training data
rf = GridSearchCV(rf, parameters, 
                    cv=n_folds, 
                   scoring="accuracy",return_train_score=True)
rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'min_samples_leaf': range(100, 400, 50)},
#              return_train_score=True, scoring='accuracy')

# %%
# scores of GridSearch CV
scores = rf.cv_results_
pd.DataFrame(scores).head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.102772      0.137821         0.049709        0.005912
# 1       1.966005      0.201153         0.047095        0.004736
# 2       1.783520      0.092156         0.042332        0.003117
# 3       1.729458      0.091337         0.043499        0.003927
# 4       1.908932      0.241301         0.049060        0.009755
#
#   param_min_samples_leaf                     params  split0_test_score  \
# 0                    100  {'min_samples_leaf': 100}           0.820476
# 1                    150  {'min_samples_leaf': 150}           0.816905
# 2                    200  {'min_samples_leaf': 200}           0.811905
# 3                    250  {'min_samples_leaf': 250}           0.811905
# 4                    300  {'min_samples_leaf': 300}           0.810000
#
#    split1_test_score  split2_test_score  split3_test_score  ...  \
# 0           0.816905           0.819048           0.816190  ...
# 1           0.811190           0.813810           0.817381  ...
# 2           0.810238           0.815714           0.809048  ...
# 3           0.809524           0.813571           0.806905  ...
# 4           0.808571           0.811429           0.806429  ...
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.817905        0.001604                1            0.823095
# 1         0.814619        0.002277                2            0.818631
# 2         0.811333        0.002384                3            0.811548
# 3         0.810000        0.002442                4            0.812500
# 4         0.809333        0.001713                5            0.811369
#
#    split1_train_score  split2_train_score  split3_train_score  \
# 0            0.822024            0.817500            0.822619
# 1            0.816071            0.812024            0.820060
# 2            0.812857            0.812262            0.812798
# 3            0.812083            0.811845            0.811726
# 4            0.809702            0.810060            0.811905
#
#    split4_train_score  mean_train_score  std_train_score
# 0            0.820119          0.821071         0.002052
# 1            0.816250          0.816607         0.002736
# 2            0.810774          0.812048         0.000792
# 3            0.809286          0.811488         0.001133
# 4            0.812024          0.811012         0.000956
#
# [5 rows x 21 columns]

# %%
# plotting accuracies with min_samples_leaf
plt.figure()
plt.plot(scores["param_min_samples_leaf"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_min_samples_leaf"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("min_samples_leaf")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ### Tuning min_samples_split

# %%
# GridSearchCV to find optimal min_samples_split
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'min_samples_split': range(200, 500, 50)}

# instantiate the model
rf = RandomForestClassifier()


# fit tree on training data
rf = GridSearchCV(rf, parameters, 
                    cv=n_folds, 
                   scoring="accuracy",return_train_score=True)
rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'min_samples_split': range(200, 500, 50)},
#              return_train_score=True, scoring='accuracy')

# %%
# scores of GridSearch CV
scores = rf.cv_results_
pd.DataFrame(scores).head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.969372      0.165777         0.055656        0.005887
# 1       3.007794      0.090164         0.061172        0.006284
# 2       2.875402      0.131205         0.054545        0.001785
# 3       2.686413      0.052715         0.053946        0.003758
# 4       2.639368      0.100848         0.050410        0.001817
#
#   param_min_samples_split                      params  split0_test_score  \
# 0                     200  {'min_samples_split': 200}           0.824286
# 1                     250  {'min_samples_split': 250}           0.823095
# 2                     300  {'min_samples_split': 300}           0.822143
# 3                     350  {'min_samples_split': 350}           0.822381
# 4                     400  {'min_samples_split': 400}           0.822857
#
#    split1_test_score  split2_test_score  split3_test_score  ...  \
# 0           0.819762           0.830000           0.823333  ...
# 1           0.820238           0.830476           0.820952  ...
# 2           0.820238           0.829048           0.820000  ...
# 3           0.820476           0.829048           0.821667  ...
# 4           0.819762           0.829524           0.821667  ...
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.823429        0.003763                1            0.827619
# 1         0.823333        0.003698                2            0.825417
# 2         0.822286        0.003475                6            0.825357
# 3         0.823048        0.003062                4            0.823988
# 4         0.822810        0.003530                5            0.823393
#
#    split1_train_score  split2_train_score  split3_train_score  \
# 0            0.828810            0.827321            0.828988
# 1            0.827619            0.824881            0.827202
# 2            0.825774            0.823214            0.826131
# 3            0.826012            0.822917            0.824643
# 4            0.825655            0.822619            0.825476
#
#    split4_train_score  mean_train_score  std_train_score
# 0            0.828512          0.828250         0.000661
# 1            0.826607          0.826345         0.001042
# 2            0.825417          0.825179         0.001021
# 3            0.823929          0.824298         0.001020
# 4            0.824464          0.824321         0.001174
#
# [5 rows x 21 columns]

# %%
# plotting accuracies with min_samples_split
plt.figure()
plt.plot(scores["param_min_samples_split"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_min_samples_split"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("min_samples_split")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# Final Model

# %% [markdown]
# ## Final model

# %%
# model with the best hyperparameters
from sklearn.ensemble import RandomForestClassifier
rfc1 = RandomForestClassifier(bootstrap=True,
                             min_samples_leaf=100, 
                             min_samples_split=200,
                             max_features=18)

# %%
# fit
rfc1.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_features=18, min_samples_leaf=100,
#                        min_samples_split=200)

# %%
# predict
predictions1 = rfc1.predict(X_test)

# %%
# evaluation metrics
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(accuracy_score(y_test,predictions1))
# Out:
# 0.8167777777777778

# %%
print(classification_report(y_test,predictions)) # old model
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      6927
#            1       0.68      0.38      0.49      2073
#
#     accuracy                           0.82      9000
#    macro avg       0.76      0.66      0.69      9000
# weighted avg       0.80      0.82      0.80      9000

# %%
print(classification_report(y_test,predictions1)) # optimized model
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      6927
#            1       0.70      0.35      0.47      2073
#
#     accuracy                           0.82      9000
#    macro avg       0.77      0.65      0.68      9000
# weighted avg       0.80      0.82      0.79      9000

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[6553  374]
#  [1278  795]]
