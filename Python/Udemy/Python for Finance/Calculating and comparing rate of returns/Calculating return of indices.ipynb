# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
ticker = ['^NSEI','^BSESN']

index_data = pd.DataFrame()

for t in ticker :
    index_data[t] = wb.DataReader(t,data_source='yahoo',start='2011-01-01')['Adj Close']

# %%
index_data
# Out:
#                    ^NSEI        ^BSESN
# Date
# 2011-01-03   6157.600098  20561.050781
# 2011-01-04   6146.350098  20498.720703
# 2011-01-05   6079.799805  20301.099609
# 2011-01-06   6048.250000  20184.740234
# 2011-01-07   5904.600098  19691.810547
# ...                  ...           ...
# 2022-01-17  18308.099609  61308.910156
# 2022-01-18  18113.050781  60754.859375
# 2022-01-19  17938.400391  60098.820312
# 2022-01-20  17757.000000  59464.621094
# 2022-01-21  17617.150391  59037.179688
#
# [2705 rows x 2 columns]

# %%
(index_data / index_data.iloc[0] * 100).plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>
